# %%
x = var('x')
f = x^2 + 1; f
# Out:
# x^2 + 1

# %%
plot(f, (x, -2, 2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
df = diff(f, x); df
# Out:
# 2*x

# %%
plot(df, (x, -2, 2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
d2f = diff(df, x); d2f
# Out:
# 2

# %%
plot(d2f, (x, -2, 2))
# Out:
# Graphics object consisting of 1 graphics primitive
