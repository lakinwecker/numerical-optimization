# %%
def f(x,y):
    return math.sin(y^2+x^2)/math.sqrt(x^2+y^2+0.0001)
P = plot3d(f,(-3,3),(-3,3), adaptive=True, color=rainbow(60, 'rgbtuple'), max_bend=.1, max_depth=15, viewer="threejs")
P.show()
# Out:
# Graphics3d Object
# /usr/lib/python2.7/json/encoder.py:207: DeprecationWarning: Interpreting naive datetime as local 2017-10-11 13:25:57.644957. Please add timezone info to timestamps.
#   chunks = self.iterencode(o, _one_shot=True)
